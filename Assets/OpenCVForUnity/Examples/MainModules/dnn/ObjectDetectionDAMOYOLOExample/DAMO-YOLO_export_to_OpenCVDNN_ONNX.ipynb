# %% [markdown]
# Reference page:
# https://zenn.dev/naviplus/articles/4245e91bede151

# %%
# @title Clone GitHub repository, install dependencies.
# !git clone https://github.com/tinyvision/damo-yolo.git
# !pip install -e damo-yolo/
# Out:
# Cloning into 'damo-yolo'...
# remote: Enumerating objects: 646, done.
# remote: Counting objects: 100% (142/142), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 646 (delta 122), reused 111 (delta 111), pack-reused 504 (from 1)
# Receiving objects: 100% (646/646), 34.37 MiB | 33.68 MiB/s, done.
# Resolving deltas: 100% (387/387), done.
# Obtaining file:///content/damo-yolo
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 3.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 110.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 91.7 MB/s eta 0:00:00
# ...

# %%
# @title Download a pretrained model.
# !wget https://idstcv.oss-cn-zhangjiakou.aliyuncs.com/DAMO-YOLO/release_model/clean_model_0317/damoyolo_tinynasL20_T_420.pth
# Out:
# --2025-03-30 18:47:47--  https://idstcv.oss-cn-zhangjiakou.aliyuncs.com/DAMO-YOLO/release_model/clean_model_0317/damoyolo_tinynasL20_T_420.pth
# Resolving idstcv.oss-cn-zhangjiakou.aliyuncs.com (idstcv.oss-cn-zhangjiakou.aliyuncs.com)... 39.98.14.82
# Connecting to idstcv.oss-cn-zhangjiakou.aliyuncs.com (idstcv.oss-cn-zhangjiakou.aliyuncs.com)|39.98.14.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35830345 (34M) [application/octet-stream]
# Saving to: ‘damoyolo_tinynasL20_T_420.pth’
#
# damoyolo_tinynasL20 100%[===================>]  34.17M  9.11MB/s    in 3.8s
#
# 2025-03-30 18:47:52 (9.11 MB/s) - ‘damoyolo_tinynasL20_T_420.pth’ saved [35830345/35830345]

# %%
# @title The code as it is will generate an error, so modify the lines in the following file.

# damo-yolo/tools/demo.py#L321
# - vis_res = infer_engine.visualize(origin_img, bboxes, scores, cls_inds, conf=args.conf, save_name=os.path.basename(args.path), save_result=args.save_result)

# + image_cv = cv2.cvtColor(origin_img, cv2.COLOR_RGB2BGR)
# + vis_res = infer_engine.visualize(image_cv, bboxes, scores, cls_inds, conf=args.conf, save_name=os.path.basename(args.path), save_result=args.save_result)

# %%
# @title The code as it is will generate an error, so modify the lines in the following file.

# damo-yolo/tools/demo.py#L253
# - cv2.imwrite(save_path, vis_img[:, :, ::-1])

# + cv2.imwrite(save_path, cv2.cvtColor(vis_img[:, :, ::-1], cv2.COLOR_RGB2BGR))

# %%
# @title Run detection demo.
!(cd damo-yolo && python tools/demo.py image -f configs/damoyolo_tinynasL20_T.py --engine ../damoyolo_tinynasL20_T_420.pth --conf 0.6 --infer_size 640 640 --device cuda --path ./assets/dog.jpg)
# Out:
# Inference with torch engine!
# save visualization results at ./demo/dog.jpg

# %%
# @title Install the necessary packages to export ONNX model.
# !pip install onnx==1.8.1
# !pip install onnxruntime==1.8.0
# !pip install onnx-simplifier==0.3.5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 45.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for onnx (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ...
#   ERROR: Failed building wheel for onnx
# Failed to build onnx
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (onnx)
# ERROR: Could not find a version that satisfies the requirement onnxruntime==1.8.0 (from versions: 1.15.0, 1.15.1, 1.16.0, 1.16.1, 1.16.2, 1.16.3, 1.17.0, 1.17.1, 1.17.3, 1.18.0, 1.18.1, 1.19.0, 1.19.2, 1.20.0, 1.20.1, 1.21.0)
# ERROR: No matching distribution found for onnxruntime==1.8.0
# ...

# %%
# @title The code as it is will generate an error, so modify the lines in the following file.

# damo-yolo/tools/converter.py#L238
# - torch.onnx._export(

# + torch.onnx.export(

# %%
# @title Export to ONNX models.
!(cd damo-yolo && python tools/converter.py -f configs/damoyolo_tinynasL20_T.py -c ../damoyolo_tinynasL20_T_420.pth --batch_size 1 --img_size 640 --device cuda)
# Out:
# 2025-03-30 19:13:07.923 | INFO     | __main__:main:180 - args value: Namespace(mode='onnx', config_file='configs/damoyolo_tinynasL20_T.py', benchmark=False, ckpt='../damoyolo_tinynasL20_T_420.pth', trt=False, trt_type='fp32', batch_size=1, img_size=640, input='images', output='output', opset=11, end2end=False, ort=False, trt_eval=False, with_preprocess=False, topk_all=100, iou_thres=0.65, conf_thres=0.05, device='cuda', opts=[])
# 2025-03-30 19:13:08.349 | INFO     | __main__:main:210 - loading checkpoint from ../damoyolo_tinynasL20_T_420.pth.
# 2025-03-30 19:16:01.921 | INFO     | __main__:main:219 - backbone's params(M): 2.17, flops(G): 7.97, latency(ms): 137.644
# neck's params(M): 5.71, flops(G): 8.24, latency(ms): 105.131
# head's params(M): 0.60, flops(G): 1.91, latency(ms): 32.567
# total latency(ms): 336.343, total flops(G): 18.12, total params(M): 8.48
#
# ...
